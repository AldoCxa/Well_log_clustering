# %% [markdown]
# <h1 align=center>
#     <font size = 5>Well logging Clustering</font>
# </h1>

# %% [markdown]
# ## Introduction
#
# Data is only useful when you are able to discover the insights, however, it becomes something difficult to achive in large data. A good aproach to solve this problem is segmentation. in the data science field it is called clustering.
# There are many models for clustering, this time, we will use a model that is considering the simpliest amongst them, K-means.

# %% [markdown]
# By clustering well logging, it becomes easier for us to see correlations between areas aparently different, which means a better understanding of the whole formation.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMean
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Getting data

# %% [markdown]
# The data used in this notebook was downloaded from <a href="https://catalog.data.gov/dataset/logs-and-data-from-utah-forge-deep-well-58-32-mu-esw1-efac6"> www.data.gov </a>.  This dataset is intended for public access and use.

# %% [markdown]
# Read de csv file with all the data logs

# %%
pd.set_option('display.max_columns', None)
#Create a dataframe
df=pd.read_csv('Run2_TCOM_Main.csv')
df.drop(labels='Unnamed: 0', axis=1, inplace=True)
df
# Out:
#          DEPT      AF10      AF20      AF30       AF60       AF90       AO10  \
# 0        10.5     1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 1        11.0     1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 2        11.5     1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 3        12.0     1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 4        12.5     1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# ...       ...       ...       ...       ...        ...        ...        ...
# 15123  7572.0  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 15124  7572.5  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 15125  7573.0  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 15126  7573.5  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 15127  7574.0  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
#
#            AO20      AO30      AO60       AO90       AT10      AT20      AT30  \
# 0        0.5586    2.1295    1.7824     2.5706     1.1898    0.4901   28.0289
# 1        0.5586    2.1295    1.7824     2.5706     1.1898    0.4901   28.0289
# 2        0.5586    2.1295    1.7824     2.5706     1.1898    0.4901   28.0289
# 3        0.5586    2.1295    1.7824     2.5706     1.1898    0.4901   28.0289
# 4        0.5586    2.1295    1.7824     2.5706     1.1898    0.4901   28.0289
# ...         ...       ...       ...        ...        ...       ...       ...
# 15123  172.8385  130.5535  489.0653  1240.9810  1950.0000  183.9162  133.9417
# 15124  172.8385  130.5535  489.0653  1240.9810  1950.0000  183.9162  133.9417
# 15125  172.8385  130.5535  489.0653  1240.9810  1950.0000  183.9162  133.9417
# 15126  172.8385  130.5535  489.0653  1240.9810  1950.0000  183.9162  133.9417
# 15127  172.8385  130.5535  489.0653  1240.9810  1950.0000  183.9162  133.9417
#
#            AT60       AT90      AORT       AORX       CDF      CFTC  \
# 0       70.7004    19.7369    1.7765     1.2661  823.5559  472.7008
# 1       70.7004    19.7369    1.7765     1.2661  823.5559  472.7008
# 2       70.7004    19.7369    1.7765     1.2661  823.5559  472.7008
# 15124 -999.25 -999.2500    0.5000     5.4373   7.4659   1.8642   0.5000
# 15125 -999.25 -999.2500    0.5000     5.4373   7.4659   1.8642   0.5000
# 15126 -999.25 -999.2500    0.5000     5.4373   7.4659   1.8642   0.5000
# 15127 -999.25 -999.2500    0.5000     5.4373   7.4659   1.8642   0.5000
#
# [15128 rows x 62 columns]

# %% [markdown]
# ## Ploting Data

# %% [markdown]
# Create a new dataframe, we can set the dept range of the data we want to display

# %%
Min= 0
Max= 7600

logs= df[(df.DEPT>Min) & (df.DEPT<Max)]

# %% [markdown]
# Chose the columns you want to plot an set them in the right measurement units and scale

# %%
fig, ax= plt.subplots(nrows=1, ncols=3,figsize=(15, 80))

for a in ax:
    a.set_yticks(np.arange(0, max(logs['DEPT'].values), 100.0)) #set the X intervals 
    a.set_ylim( Min, Max )
    a.invert_yaxis()

#------------------|column 1|--------   
ax01= ax[0].twiny()
ax01.set_xlim(0,300)
ax01.plot( logs['GR'].values, logs['DEPT'].values, color='green') #select the data and the color
ax01.set_xlabel('GR[api]',color='green') #set the name
ax01.spines['top'].set_position(('outward',80)) #Set range line 
ax01.tick_params(axis='x', colors='green')  #set the color of the 'spine'
ax01.grid(True)

c='red'
ax02= ax[0].twiny()
ax02.set_xlim(-200,200)
ax02.plot( logs['SP'].values, logs['DEPT'].values, color=c) 
ax02.set_xlabel('SP',color=c) 
ax02.spines['top'].set_position(('outward',40))
ax02.tick_params(axis='x', colors=c)

c='gray'
ax03= ax[0].twiny()
ax03.set_xlim(6,16)
ax03.plot( logs['HCAL'].values, logs['DEPT'].values,'--', color=c) 
ax03.set_xlabel('HCAL',color='black') 
ax03.spines['top'].set_position(('outward',0))
ax03.tick_params(axis='x', colors=c)

#------------------|column 2|-------- 
c='blue'
ax11= ax[1].twiny()
ax11.set_xscale('log') #set logaritmic scale
#ax11.set_xlim(0,100)
ax11.plot( logs['AT60'].values, logs['DEPT'].values, color=c) 
ax11.set_xlabel('AT60',color=c) 
ax11.spines['top'].set_position(('outward',40))
ax11.tick_params(axis='x', colors=c)
ax11.grid(True)

c='gray'
ax12= ax[1].twiny()
ax12.set_xscale('log')
#ax12.set_xlim(0,100)
ax12.plot( logs['AT10'].values, logs['DEPT'].values, color=c) 
ax12.set_xlabel('AT10',color=c) 
ax12.spines['top'].set_position(('outward',0))
ax12.tick_params(axis='x', colors=c)

#------------------|column 3|-------- 
c='blue'
ax21= ax[2].twiny()
ax21.set_xlim(-.15,.45)
ax21.plot( logs['NPOR'].values, logs['DEPT'].values, color=c) 
ax21.set_xlabel('NPOR',color=c) 
ax21.spines['top'].set_position(('outward',40))
ax21.tick_params(axis='x', colors=c)
ax21.grid(True)

c='Red'
ax22= ax[2].twiny()
ax22.set_xlim(-.15,.45)
ax22.plot( logs['DPHZ'].values, logs['DEPT'].values, color=c) 
ax22.set_xlabel('DPHZ',color=c) 
ax22.spines['top'].set_position(('outward',0))
ax22.tick_params(axis='x', colors=c)

c='green'
ax22= ax[2].twiny()
ax22.set_xlim(0,10)
ax22.plot( logs['PEFZ'].values, logs['DEPT'].values, color=c) 
ax22.set_xlabel('PEFZ',color=c) 
ax22.spines['top'].set_position(('outward',80))
ax22.tick_params(axis='x', colors=c)

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# in the first 50 meters of tne well logging, the tools present abnormal responses. Those responses will  produce errors in the mathematical model. in order to avoid those disturbances, we will drop the first 100 m.
#
# lets look for this position. (100m)

# %%
df[df['DEPT']==100]
# Out:
#       DEPT    AF10    AF20     AF30    AF60      AF90    AO10    AO20    AO30  \
# 179  100.0  1.0669  0.3632  22.5882  1950.0  116.7097  0.8871  0.4395  2.3142
#
#        AO60    AO90    AT10   AT20     AT30      AT60     AT90   AORT    AORX  \
# 179  3.4848  6.1007  1.0229  0.419  15.1079  170.0617  13.0856  2.788  1.0086
#
#           CDF      CFTC       CNTC      CTEM  DCAL    DNPH    DPHZ    DSOZ  \
# 179  775.8344  327.1172  1266.4661  143.8118   0.0 -0.0209  0.2018  0.4053
#
#         ECGR      ED    GDEV       GR  GR_EDTC     GTEM    HCAL  HDRA    HDRB  \
# 179  42.9006 -0.0059  1.5123  34.2507  21.8787  119.368  3.4788  0.26  0.9354
#
#          HGR    HMIN    HMNO    HNPO    HPRA    HTNP      ND    NPHI   NPOR  \
# 179  32.4997  0.6103  0.4127  0.4556 -1.8675  0.5077 -0.0784  0.5574  0.459
#
#        PEFZ  PXND_HILT   RHOZ    RSOZ  RWA_HILT    RXO8    RXOZ       SP  \
# 179  9.9982     0.3374  2.317  0.3046   19.3641  0.4235  0.4235  76.9531
#
#        SPAR  STIT      TENS    TNPH  HTNP_SAN    ATCO10     ATCO20   ATCO30  \
# 179  76.725   0.0  873.0001  0.5069    0.5077  977.6158  2386.7688  66.1906
#
#      ATCO60   ATCO90
# 179  5.8802  76.4198

# %%
x = df[179:]
x.head()
# Out:
#       DEPT    AF10    AF20     AF30    AF60      AF90    AO10    AO20    AO30  \
# 179  100.0  1.0669  0.3632  22.5882  1950.0  116.7097  0.8871  0.4395  2.3142
# 180  100.5  1.0799  0.3687  27.2645  1950.0  111.7548  1.0483  0.4580  2.9169
# 181  101.0  1.0912  0.3746  32.5201  1950.0   96.7937  1.1655  0.4950  3.7339
# 182  101.5  1.0902  0.3798  34.3147  1950.0   80.3259  1.0560  0.4639  2.3942
# 183  102.0  1.0756  0.3861  38.1528  1950.0   64.0619  1.0107  0.4528  2.9139
#
#        AO60    AO90    AT10    AT20     AT30      AT60     AT90    AORT  \
# 179  3.4848  6.1007  1.0229  0.4190  15.1079  170.0617  13.0856  2.7880
# 180  2.3608  4.0447  1.0690  0.4308  27.4326  150.2215  16.9982  2.6946
# 181  3.3036  5.3531  1.0871  0.4419  48.7968  118.8006  12.6155  2.5636
# 182  2.8136  3.7452  1.0664  0.4479  34.1096   89.4196  12.6858  2.4614
# 183  1.8001  2.2353  1.0046  0.4610  35.8575   73.3911   7.9139  2.4405
#
# %% [markdown]
# Check for null values

# %%
x.isnull().sum()
# Out:
# DEPT      0
# AF10      0
# AF20      0
# AF30      0
# AF60      0
#          ..
# ATCO10    0
# ATCO20    0
# ATCO30    0
# ATCO60    0
# ATCO90    0
# Length: 62, dtype: int64

# %% [markdown]
# As we can see, there are not null values, but we still have to normalize the dataset.It helps mathematical-based algorithms to interpret features with different magnitudes and distributions equally. We use StandardScaler() to normalize our dataset.

# %%
x_nor = StandardScaler().fit_transform(x)
x_nor
# Out:
# array([[-1.73193495, -1.11389697, -0.54865804, ...,  0.75250703,
#         -0.44489088,  0.07320247],
#        [-1.73170322, -1.11388342, -0.5486467 , ...,  0.2027381 ,
#         -0.43377683, -0.09031439],
#        [-1.73147149, -1.11387165, -0.54863452, ..., -0.0923132 ,
#         -0.40857915,  0.09967673],
#        ...,
#        [ 1.73147149,  0.91705273, -0.061865  , ..., -0.33315243,
#         -0.50236454, -0.63255296],
#        [ 1.73170322,  0.91705273, -0.061865  , ..., -0.33315243,
#         -0.50236454, -0.63255296],
#        [ 1.73193495,  0.91705273, -0.061865  , ..., -0.33315243,
#         -0.50236454, -0.63255296]])

# %% [markdown]
# ## Clustering Data

# %%
kmeans = KMeans( n_clusters=5, init='k-means++', n_init=25, max_iter=400, random_state=0).fit(x_nor)
kmeans.labels_[0:15]
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])

# %% [markdown]
# add the cluster labels to de dataframe

# %%
# df.drop('Cluster Labels', axis = 1, inplace=True)
df_clusters = x
df_clusters.insert(0, 'Cluster Labels', kmeans.labels_)
df_clusters.head()
# Out:
#      Cluster Labels   DEPT    AF10    AF20     AF30    AF60      AF90    AO10  \
# 179               3  100.0  1.0669  0.3632  22.5882  1950.0  116.7097  0.8871
# 180               3  100.5  1.0799  0.3687  27.2645  1950.0  111.7548  1.0483
# 181               3  101.0  1.0912  0.3746  32.5201  1950.0   96.7937  1.1655
# 182               3  101.5  1.0902  0.3798  34.3147  1950.0   80.3259  1.0560
# 183               3  102.0  1.0756  0.3861  38.1528  1950.0   64.0619  1.0107
#
#        AO20    AO30    AO60    AO90    AT10    AT20     AT30      AT60  \
# 179  0.4395  2.3142  3.4848  6.1007  1.0229  0.4190  15.1079  170.0617
# 180  0.4580  2.9169  2.3608  4.0447  1.0690  0.4308  27.4326  150.2215
# 181  0.4950  3.7339  3.3036  5.3531  1.0871  0.4419  48.7968  118.8006
# 182  0.4639  2.3942  2.8136  3.7452  1.0664  0.4479  34.1096   89.4196
# 183  0.4528  2.9139  1.8001  2.2353  1.0046  0.4610  35.8575   73.3911
#
#         AT90    AORT    AORX       CDF      CFTC       CNTC      CTEM  DCAL  \
# 179  13.0856  2.7880  1.0086  775.8344  327.1172  1266.4661  143.8118   0.0
# 180  16.9982  2.6946  1.0042  767.7578  309.4816  1295.9174  143.8118   0.0
# 181  12.6155  2.5636  0.9881  773.0978  325.6334  1293.8101  143.8118   0.0
# 182  12.6858  2.4614  0.9547  777.0771  306.5539  1279.6381  143.8118   0.0
# 183   7.9139  2.4405  0.9064  771.4240  297.2666  1257.4928  143.8118   0.0
#
#        DNPH    DPHZ    DSOZ     ECGR      ED    GDEV       GR  GR_EDTC  \
# 179 -0.0209  0.2018  0.4053  42.9006 -0.0059  1.5123  34.2507  21.8787
# 180 -0.0114  0.1974  0.4055  41.3992 -0.0060  1.0275  33.0520  25.4397
# 181 -0.0191  0.1954  0.4026  42.0430 -0.0060  0.6390  33.5660  29.5028
# 182 -0.0120  0.1974  0.3986  41.5422 -0.0061  1.1088  33.1662  31.0151
# 183 -0.0090  0.1923  0.4019  43.5442 -0.0062  0.0000  34.7645  28.0309
#
#         GTEM    HCAL    HDRA    HDRB      HGR    HMIN    HMNO    HNPO    HPRA  \
# 179  119.368  3.4788  0.2600  0.9354  32.4997  0.6103  0.4127  0.4556 -1.8675
# 180  119.368  3.4667  0.2648  0.9438  35.1644  0.6070  0.4110  0.6252 -2.1512
# 181  119.368  3.4788  0.2657  0.9520  33.5660  0.6082  0.4109  0.5476 -2.1422
# 182  119.368  3.4547  0.2607  0.9565  33.5657  0.6033  0.4086  0.6681 -1.8202
# 183  119.368  3.4547  0.2614  0.9730  31.7008  0.6007  0.4080  0.6458 -1.3604
#
#        HTNP      ND    NPHI    NPOR     PEFZ  PXND_HILT    RHOZ    RSOZ  \
# 179  0.5077 -0.0784  0.5574  0.4590   9.9982     0.3374  2.3170  0.3046
# 180  0.6116 -0.0792  0.5058  0.6073  10.0000     0.3675  2.3242  0.3048
# 181  0.5323 -0.0800  0.5654  0.5554  10.0000     0.3409  2.3275  0.3046
# 182  0.6019 -0.0808  0.5684  0.5984  10.0000     0.3658  2.3244  0.3034
# 183  0.6426 -0.0816  0.5615  0.6068   9.9567     0.3726  2.3327  0.3024
#
#      RWA_HILT    RXO8    RXOZ       SP     SPAR  STIT      TENS    TNPH  \
# 179   19.3641  0.4235  0.4235  76.9531  76.7250   0.0  873.0001  0.5069
# 180   20.2909  0.4226  0.4224  76.3281  76.6533   0.0  852.0000  0.6009
# 181   13.8054  0.4213  0.4214  76.5625  76.5747   0.0  837.0000  0.5309
# 182   11.9637  0.4203  0.4207  75.7639  76.2017   0.0  899.0000  0.5966
# 183   10.1873  0.4209  0.4209  75.9375  76.1153   0.0  876.0000  0.6198
#
#      HTNP_SAN    ATCO10     ATCO20   ATCO30   ATCO60    ATCO90
# 179    0.5077  977.6158  2386.7688  66.1906   5.8802   76.4198
# 180    0.6116  935.4244  2320.9966  36.4529   6.6568   58.8299
# 181    0.5323  919.9154  2262.8186  20.4932   8.4175   79.2677
# 182    0.6019  937.7034  2232.6646  29.3172  11.1832   78.8280
# 183    0.6426  995.3771  2169.1350  27.8881  13.6256  126.3597

# %%
Min=1500
Max=2500

# %% [markdown]
# plot the data with the cluster labels

# %%
logs = x[(x.DEPT>Min) & (x.DEPT<Max)]

# %%
fig, ax= plt.subplots(nrows=1, ncols=4,figsize=(18, 80))

for a in ax:
    a.set_yticks(np.arange(min(logs['DEPT'].values), max(logs['DEPT'].values), 100.0))
    a.set_ylim(  Min, Max  )
    a.invert_yaxis()

    
    
#------------------||--------   
ax01= ax[0].twiny()
ax01.set_xlim(0,300)
ax01.plot( logs['GR'].values, logs['DEPT'].values, color='green') #select the data and the color
ax01.set_xlabel('GR[api]',color='green') #set the name
ax01.spines['top'].set_position(('outward',80)) #Set range line 
ax01.tick_params(axis='x', colors='green')  #set the color of the 'spine'
ax01.grid(True)


c='red'
ax02= ax[0].twiny()
ax02.set_xlim(-200,200)
ax02.plot( logs['SP'].values, logs['DEPT'].values, color=c) 
ax02.set_xlabel('SP',color=c) 
ax02.spines['top'].set_position(('outward',40))
ax02.tick_params(axis='x', colors=c)


c='gray'
ax03= ax[0].twiny()
ax03.set_xlim(6,16)
ax03.plot( logs['HCAL'].values, logs['DEPT'].values,'--', color=c) 
ax03.set_xlabel('HCAL',color='black') 
ax03.spines['top'].set_position(('outward',0))
ax03.tick_params(axis='x', colors=c)

#-----------------------------
c='purple'
ax11= ax[1].twiny()
ax11.set_xscale('log')
ax11.plot( logs['AT60'].values, logs['DEPT'].values, color=c) 
ax11.set_xlabel('AT60',color=c) 
ax11.spines['top'].set_position(('outward',40))
ax11.tick_params(axis='x', colors=c)
ax11.grid(True)

c='gray'
ax12= ax[1].twiny()
ax12.set_xscale('log')
ax12.plot( logs['AT10'].values, logs['DEPT'].values, color=c) 
ax12.set_xlabel('AT10',color=c) 
ax12.spines['top'].set_position(('outward',0))
ax12.tick_params(axis='x', colors=c)

#-----------------------------------
c='blue'
ax21= ax[2].twiny()
ax21.set_xlim(-.15,.45)
ax21.plot( logs['NPOR'].values, logs['DEPT'].values, color=c) 
ax21.set_xlabel('NPOR',color=c) 
ax21.spines['top'].set_position(('outward',40))
ax21.tick_params(axis='x', colors=c)
ax21.grid(True)

c='Red'
ax22= ax[2].twiny()
ax22.set_xlim(-.15,.45)
ax22.plot( logs['DPHZ'].values, logs['DEPT'].values, color=c) 
ax22.set_xlabel('DPHZ',color=c) 
ax22.spines['top'].set_position(('outward',0))
ax22.tick_params(axis='x', colors=c)


c='green'
ax22= ax[2].twiny()
ax22.set_xlim(0,10)
ax22.plot( logs['PEFZ'].values, logs['DEPT'].values, color=c) 
ax22.set_xlabel('PEFZ',color=c) 
ax22.spines['top'].set_position(('outward',80))
ax22.tick_params(axis='x', colors=c)
            

#------------------|  fourth  |--------------------
ax31=ax[3].twiny()
ax31.set_xlabel('Cluster labels',color=c) 
#ax31.plot( df_clusters['Cluster Labels'].values, logs['DEPT'].values, color=c)
# Out:
# Text(0.5, 0, 'Cluster labels')

# %%
          df_clusters['Cluster Labels'].value_counts()
# Out:
# 3    4337
# 2    3639
# 1    2915
# 0    2363
# 4    1874
# Name: Cluster Labels, dtype: int64

# %% [markdown]
# We can check the frequency of each cluster by making a graph

# %%
names=['0','1','2','3','4']
values=df_clusters['Cluster Labels'].value_counts().sort_index()


plt.figure(figsize=(8, 5))
plt.bar(names, values)
plt.xlabel('Cluster')
plt.show()
